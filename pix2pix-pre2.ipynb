# %% [markdown]
# Начало обучения

# %%
# !pip install easycolab
import easycolab as ec
ec.mount()
import os
os.chdir("pix2pix-pre2/")
# !pip install tensorflow==1.13.1
# !pip install tensorflow-gpu==1.13.1
# !python pix2pix.py --png16bits --mode train \
    --output_dir multi_train --max_epochs 10 \
    --input_dir multi/train --which_direction AtoB
# Out:
# ...
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Opening directory /content/gdrive/My Drive/
# Done!
# ...
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# ...

# %% [markdown]
# Визуализация метрик

# %%
# !pip install easycolab
import easycolab as ec
ec.mount()
import os
os.chdir("pix2pix-pre2/")
# %load_ext tensorboard.notebook
# %tensorboard --logdir=multi_train

# %% [markdown]
# Продолжение обучения

# %%
# !pip install easycolab
import easycolab as ec
ec.mount()
import os
os.chdir("pix2pix-pre2/")
# !pip install tensorflow==1.13.1
# !pip install tensorflow-gpu==1.13.1
# !python pix2pix.py --png16bits --mode train \
    --output_dir multi_train --checkpoint multi_train \
    --max_epochs 10 --input_dir multi/train \
    --which_direction AtoB
# Out:
# ...
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Opening directory /content/gdrive/My Drive/
# Done!
# ...
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# ...

# %% [markdown]
# Проверка

# %%
# !pip install easycolab
import easycolab as ec
ec.mount()
import os
os.chdir("pix2pix-pre2/")
# !pip install tensorflow==1.13.1
# !python pix2pix.py --png16bits --mode test \
    --output_dir multi_test1000 --input_dir multi/val \
    --checkpoint multi_train
# Out:
# ...
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Opening directory /content/gdrive/My Drive/
# Done!
# ...
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# ...

# %% [markdown]
# Экспорт

# %%
# !pip install easycolab
import easycolab as ec
ec.mount()
import os
os.chdir("pix2pix-pre2/")
# !pip install tensorflow==1.13.1
# !python pix2pix.py --png16bits --mode export \
    --output_dir export1000 --checkpoint multi_train
# Out:
# ...
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Opening directory /content/gdrive/My Drive/
# Done!
# ...
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# ...

# %% [markdown]
# Проверка на одном изображении

# %%
# !pip install easycolab
import easycolab as ec
ec.mount()
import os
os.chdir("pix2pix-pre2/")
# !pip install tensorflow==1.13.1
# !python process-local.py --input_file input.png \
    --model_dir export200 --output_file output/output200.png
# !python process-local.py --input_file input.png \
    --model_dir export240 --output_file output/output240.png
# !python process-local.py --input_file input.png \
    --model_dir export280 --output_file output/output280.png
# !python process-local.py --input_file input.png \
    --model_dir export320 --output_file output/output320.png
# !python process-local.py --input_file input.png \
    --model_dir export360 --output_file output/output360.png
# !python process-local.py --input_file input.png \
    --model_dir export400 --output_file output/output400.png
# !python process-local.py --input_file input.png \
    --model_dir export440 --output_file output/output440.png
# !python process-local.py --input_file input.png \
    --model_dir export480 --output_file output/output480.png
# !python process-local.py --input_file input.png \
    --model_dir export520 --output_file output/output520.png
# !python process-local.py --input_file input.png \
    --model_dir export560 --output_file output/output560.png
# !python process-local.py --input_file input.png \
    --model_dir export600 --output_file output/output600.png
# !python process-local.py --input_file input.png \
    --model_dir export640 --output_file output/output640.png
# !python process-local.py --input_file input.png \
    --model_dir export680 --output_file output/output680.png
# !python process-local.py --input_file input.png \
    --model_dir export720 --output_file output/output720.png
# !python process-local.py --input_file input.png \
    --model_dir export760 --output_file output/output760.png
# !python process-local.py --input_file input.png \
    --model_dir export800 --output_file output/output800.png
# !python process-local.py --input_file input.png \
    --model_dir export840 --output_file output/output840.png
# !python process-local.py --input_file input.png \
    --model_dir export880 --output_file output/output880.png
# !python process-local.py --input_file input.png \
    --model_dir export920 --output_file output/output920.png
# !python process-local.py --input_file input.png \
    --model_dir export960 --output_file output/output960.png
# !python process-local.py --input_file input.png \
    --model_dir export1000 --output_file output/output1000.png
# Out:
# ...
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Opening directory /content/gdrive/My Drive/
# Done!
# ...
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# ...
